# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
#import the datasets
phone = pd.read_csv("phone.csv")
tablet = pd.read_csv("tablet.csv")
monitor = pd.read_csv("monitors.csv")

# %%
phone
# Out:
#                                                  phone Operating System  \
# 0                                      Apple iPhone XR              iOS
# 1                                  Apple iPhone 8 Plus              iOS
# 2                                  Apple iPhone 7 Plus              iOS
# 3                                      Apple iPhone SE              iOS
# 4                                      Apple iPhone XS              iOS
# ..                                                 ...              ...
# 259          Apple MacBook Pro 15-inch (Hi-Res screen)             OS X
# 260         Apple MacBook Pro 15-inch (Retina display)             OS X
# 261  Apple MacBook Pro 17-inch (Mid/Late 2007 - Lat...             OS X
# 262                                Panasonic BT-LH2170              SDI
# 263                               Panasonic BT-LH910GJ              SDI
#
#      Physical Size "\n\nphys size "  Physical Size cm\n\nphys size cm  \
# ...

# %%
# neigh = NearestNeighbors(n_neighbors=1)
# neigh.fit(phone)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5907ad174d87> in <module>
#       1 neigh = NearestNeighbors(n_neighbors=1)
# ----> 2 neigh.fit(phone)
#
# /usr/lib/python3.9/site-packages/sklearn/neighbors/_unsupervised.py in fit(self, X, y)
#     140             The fitted nearest neighbors estimator.
#     141         """
# --> 142         return self._fit(X)
#
# /usr/lib/python3.9/site-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     395         else:
#     396             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 397                 X = self._validate_data(X, accept_sparse='csr')
#     398
#     399         self._check_algorithm_metric()
#
# /usr/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
# ...
